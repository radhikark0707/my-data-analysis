# %% [markdown]
# <a href="https://colab.research.google.com/github/radhikark0707/my-data-analysis/blob/main/Classification_Model_Casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 4 CLASSIFICATION MODEL

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/Loan_Default.csv')

# %%
data.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness  ... co-applicant_credit_type    age  \
# 0           p1                l1  ...                      CIB  25-34
# 1           p1                l1  ...                      EXP  55-64
# 2           p1                l1  ...                      CIB  35-44
# 3           p4                l1  ...                      CIB  45-54
# 4           p1                l1  ...                      EXP  25-34
#
#    submission_of_application        LTV  Region  Security_Type  Status dtir1
# ...

# %%
data.shape
# Out:
# (148670, 34)

# %%
#There are 34 features and data frame is not displaying them all so we do as below
pd.set_option('display.max_columns',data.shape[-1])

# %%
data.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                  nob/c
# 1           p1                l1        nopc                    b/c
# 2           p1                l1        nopc                  nob/c
# 3           p4                l1        nopc                  nob/c
# 4           p1                l1        nopc                  nob/c
#
#    loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# ...

# %%
#converting feature to lower case
data.columns=data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['id', 'year', 'loan_limit', 'gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'credit_worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'interest_rate_spread', 'upfront_charges', 'term', 'neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'secured_by', 'total_units',
#        'income', 'credit_type', 'credit_score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'ltv', 'region', 'security_type',
#        'status', 'dtir1'],
#       dtype='object')

# %%
#droping columns which cant be used for information
data=data.drop(columns=['id','loan_limit','gender','approv_in_adv','loan_purpose','open_credit','business_or_commercial',
                'credit_worthiness','interest_rate_spread','upfront_charges','neg_ammortization','interest_only',
                'lump_sum_payment','construction_type','occupancy_type','secured_by','total_units','credit_type',
                'co-applicant_credit_type','submission_of_application','ltv','region','security_type'])

# %%
data=data.drop(columns=['year'])

# %%
data.columns
# Out:
# Index(['loan_type', 'loan_amount', 'rate_of_interest', 'term',
#        'property_value', 'income', 'credit_score', 'age', 'status', 'dtir1'],
#       dtype='object')

# %%
data.shape
# Out:
# (148670, 10)

# %%
pd.set_option('display.max_columns',data.shape[-1])
data.head()
# Out:
#   loan_type  loan_amount  rate_of_interest   term  property_value   income  \
# 0     type1       116500               NaN  360.0        118000.0   1740.0
# 1     type2       206500               NaN  360.0             NaN   4980.0
# 2     type1       406500              4.56  360.0        508000.0   9480.0
# 3     type1       456500              4.25  360.0        658000.0  11880.0
# 4     type1       696500              4.00  360.0        758000.0  10440.0
#
#    credit_score    age  status  dtir1
# 0           758  25-34       1   45.0
# 1           552  55-64       1    NaN
# 2           834  35-44       0   46.0
# 3           587  45-54       0   42.0
# 4           602  25-34       0   39.0

# %%
#check for duplicate and remove
data.duplicated().sum()
# Out:
# 6

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#null values
data.isnull().sum()
# Out:
# loan_type               0
# loan_amount             0
# rate_of_interest    36437
# term                   41
# property_value      15096
# income               9146
# credit_score            0
# age                   200
# status                  0
# dtir1               24115
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148664 entries, 0 to 148669
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   loan_type         148664 non-null  object
#  1   loan_amount       148664 non-null  int64
#  2   rate_of_interest  112227 non-null  float64
#  3   term              148623 non-null  float64
#  4   property_value    133568 non-null  float64
#  5   income            139518 non-null  float64
#  6   credit_score      148664 non-null  int64
#  7   age               148464 non-null  object
#  8   status            148664 non-null  int64
#  9   dtir1             124549 non-null  float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 12.5+ MB

# %%
#filling missing value
from sklearn.impute import SimpleImputer
imputer=SimpleImputer()
data[['rate_of_interest','term','property_value','income','dtir1']] = imputer.fit_transform(data[['rate_of_interest','term','property_value','income','dtir1']])

# %%
imputer=SimpleImputer(strategy='most_frequent')
data[['age']]=imputer.fit_transform(data[['age']])

# %%
data.isna().sum()
# Out:
# loan_type           0
# loan_amount         0
# rate_of_interest    0
# term                0
# property_value      0
# income              0
# credit_score        0
# age                 0
# status              0
# dtir1               0
# dtype: int64

# %% [markdown]
# Characteristics of data

# %%
data['loan_type'].min()
# Out:
# 'type1'

# %%
data['loan_type'].max()
# Out:
# 'type3'

# %%
data['loan_amount'].min()
# Out:
# 16500

# %%
data['loan_amount'].max()
# Out:
# 3576500

# %%
data['age'].value_counts()
# Out:
# age
# 45-54    34919
# 35-44    32815
# 55-64    32533
# 65-74    20744
# 25-34    19141
# >74       7175
# <25       1337
# Name: count, dtype: int64

# %%
data['rate_of_interest'].value_counts()
# Out:
# rate_of_interest
# 4.045482    36437
# 3.990000    14454
# 3.625000     8799
# 3.875000     8592
# 3.750000     8473
#             ...
# 4.700000        1
# 8.000000        1
# 7.750000        1
# 5.300000        1
# 2.700000        1
# Name: count, Length: 132, dtype: int64

# %%
data['rate_of_interest'].min()
# Out:
# 0.0

# %%
data['rate_of_interest'].max()
# Out:
# 8.0

# %%
data['property_value'].value_counts()
# Out:
# property_value
# 4.979002e+05    15096
# 3.080000e+05     2791
# 2.580000e+05     2763
# 3.580000e+05     2679
# 4.080000e+05     2537
#                 ...
# 4.648000e+06        1
# 3.878000e+06        1
# 5.758000e+06        1
# 2.618000e+06        1
# 2.698000e+06        1
# Name: count, Length: 386, dtype: int64

# %%
data['property_value'].min()
# Out:
# 8000.0

# %%
data['property_value'].max()
# Out:
# 16508000.0

# %%
msk=data['property_value']==data['property_value'].max()
data[msk]['loan_amount']
# Out:
# 17114    2476500
# Name: loan_amount, dtype: int64

# %%
msk=data['income']==data['income'].max()
data[msk]['status']
# Out:
# 62237    1
# Name: status, dtype: int64

# %%
msk=data['income']==data['income'].max()
data[msk]['rate_of_interest']
# Out:
# 62237    4.045482
# Name: rate_of_interest, dtype: float64

# %%
msk=data['income']==data['income'].min()
data[msk]['status']
# Out:
# 42        1
# 143       1
# 208       1
# 301       1
# 409       1
#          ..
# 147632    1
# 147728    1
# 148163    1
# 148197    1
# 148349    1
# Name: status, Length: 1259, dtype: int64

# %%
msk=data['income']==data['income'].min()
data[msk]['rate_of_interest'].value_counts()
# Out:
# rate_of_interest
# 4.045482    1251
# 4.125000       2
# 3.625000       1
# 2.990000       1
# 4.750000       1
# 0.000000       1
# 3.875000       1
# 4.250000       1
# Name: count, dtype: int64

# %%
#income less than 2000
data['income'].value_counts()
# Out:
# income
# 6957.392164      9146
# 0.000000         1259
# 3600.000000      1250
# 4200.000000      1243
# 4800.000000      1191
#                  ...
# 45300.000000        1
# 154440.000000       1
# 137760.000000       1
# 145560.000000       1
# 79920.000000        1
# Name: count, Length: 1002, dtype: int64

# %%
data['income'].mean()
# Out:
# 6957.392164451898

# %%
msk=data['income']<2000
msk.value_counts()
# Out:
# income
# False    140706
# True       7958
# Name: count, dtype: int64

# %%
data['income']=data['income'].apply(lambda x:x if x not in msk else data['income'].mean())

# %%
msk=data['income']<2000
msk.value_counts()
# Out:
# income
# False    148664
# Name: count, dtype: int64

# %%
data['income'].min()
# Out:
# 6957.392164451898

# %%
#rate of interest 0 correct it
data['rate_of_interest'].value_counts()
# Out:
# rate_of_interest
# 4.045482    36437
# 3.990000    14454
# 3.625000     8799
# 3.875000     8592
# 3.750000     8473
#             ...
# 4.700000        1
# 8.000000        1
# 7.750000        1
# 5.300000        1
# 2.700000        1
# Name: count, Length: 132, dtype: int64

# %%
data['rate_of_interest'].min()
# Out:
# 0.0

# %%
data['rate_of_interest'].mean()
# Out:
# 4.045481969579513

# %%
msk=data['rate_of_interest']==0
msk.value_counts()
# Out:
# rate_of_interest
# False    148663
# True          1
# Name: count, dtype: int64

# %%
data['rate_of_interest']=data['rate_of_interest'].apply(lambda x:x if x not in msk else data['rate_of_interest'].mean())

# %%
data['rate_of_interest'].min()
# Out:
# 2.125

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148664 entries, 0 to 148669
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   loan_type         148664 non-null  object
#  1   loan_amount       148664 non-null  int64
#  2   rate_of_interest  148664 non-null  float64
#  3   term              148664 non-null  float64
#  4   property_value    148664 non-null  float64
#  5   income            148664 non-null  float64
#  6   credit_score      148664 non-null  int64
#  7   age               148664 non-null  object
#  8   status            148664 non-null  int64
#  9   dtir1             148664 non-null  float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 16.5+ MB

# %%
data=pd.get_dummies(data,columns=['loan_type','age'],drop_first=True)

# %%
pd.set_option('display.max_columns',data.shape[-1])
data.head()
# Out:
#    loan_amount  rate_of_interest   term  property_value       income  \
# 0       116500          4.045482  360.0   118000.000000  6957.392164
# 1       206500          4.045482  360.0   497900.200647  6957.392164
# 2       406500          4.560000  360.0   508000.000000  6957.392164
# 3       456500          4.250000  360.0   658000.000000  6957.392164
# 4       696500          4.045482  360.0   758000.000000  6957.392164
#
#    credit_score  status      dtir1  loan_type_type2  loan_type_type3  \
# 0           758       1  45.000000            False            False
# 1           552       1  37.732932             True            False
# 2           834       0  46.000000            False            False
# 3           587       0  42.000000            False            False
# 4           602       0  39.000000            False            False
#
#    age_35-44  age_45-54  age_55-64  age_65-74  age_<25  age_>74
# 0      False      False      False      False    False    False
# ...

# %%
y=data['status']
x=data.drop(columns=['status'])

# %%
#split data into test and training set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#create and train decision tree classifier
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#prediction
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy score',accuracy_score(y_test,y_pred))
print('Confusion matrix',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score 0.9686879897756702
# Confusion matrix [[21946   453]
#  [  478  6856]]

# %%
#Random forest classifier
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

# %%
print('Accuracy score',accuracy_score(y_test,y_pred))
print('Confusion matrix',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score 0.9781387683718428
# Confusion matrix [[21889   510]
#  [  140  7194]]

# %%
#Naive bayes classifier
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=clf.predict(x_test)

# %%
print('Accuracy score',accuracy_score(y_test,y_pred))
print('Confusion matrix',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score 0.7529008172737363
# Confusion matrix [[22332    67]
#  [ 7280    54]]

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression(max_iter=1000)
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=log_reg.predict(x_test)

# %%
print('Accuracy score',accuracy_score(y_test,y_pred))
print('Confusion matrix',confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score 0.7533380419062994
# Confusion matrix [[22399     0]
#  [ 7334     0]]
